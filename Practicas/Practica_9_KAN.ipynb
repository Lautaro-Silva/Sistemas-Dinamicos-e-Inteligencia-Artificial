# %%
# Instalamos la libreria desde github

# %%
# Import KAN


# check GPUs o CPUs


# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
# Out:
# cpu
# checkpoint directory created: ./model
# saving model version 0.0

# %%
# Importar create_dataset

# create dataset f(x,y) = x*y
# Out:
# (torch.Size([1000, 2]), torch.Size([1000, 1]))

# %%
# plot KAN at initialization

# %%
# train the model
# Out:
# | train_loss: 5.74e-03 | test_loss: 6.62e-03 | reg: 6.61e+00 | : 100%|█| 50/50 [00:22<00:00,  2.20it
# saving model version 0.1

# %%
# Graficar el modelo que obtuvimos

# %%
# Eliminar elementos chicos con prune y graficar de nuevo
# Out:
# saving model version 0.2

# %%
# Ajustar de nuevo
# Out:
# | train_loss: 2.65e-04 | test_loss: 2.97e-04 | reg: 8.57e+00 | : 100%|█| 50/50 [00:14<00:00,  3.47it
# saving model version 0.3
# saving model version 0.4
# | train_loss: 2.56e-05 | test_loss: 3.06e-05 | reg: 8.57e+00 | : 100%|█| 50/50 [00:16<00:00,  2.98it
# saving model version 0.5

# %%
# Fijar funciones analiticas


if mode == "manual":
    # manual mode

elif mode == "auto":
    # automatic mode


# Ajustar
# Out:
# Best value at boundary.
# r2 is 0.9995051514816338
# saving model version 0.6
# Best value at boundary.
# r2 is 0.0038899497299473246
# r2 is not very high, please double check if you are choosing the correct symbolic function.
# saving model version 0.7
# Best value at boundary.
# r2 is 0.9995554856084466
# saving model version 0.8
# Best value at boundary.
# r2 is 0.002090602711482246
# r2 is not very high, please double check if you are choosing the correct symbolic function.
# saving model version 0.9
# Best value at boundary.
# r2 is 0.9835379470052805
# saving model version 0.10
# r2 is 0.9999964733520184
# saving model version 0.11
# skipping (0,0,0) since already symbolic
# skipping (0,0,1) since already symbolic
# skipping (0,1,0) since already symbolic
# skipping (0,1,1) since already symbolic
# skipping (1,0,0) since already symbolic
# skipping (1,1,0) since already symbolic
# saving model version 0.12
# ...

# %%
# Graficar
# Out:
# saving model version 0.15

# %%
# Modelo final
# Out:
# 0.24 - 0.36*(-x_1 + 0.99*x_2 + 0.12)**2
