# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split, WeightedRandomSampler
import torch.nn.functional as F
from torchinfo import summary
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %%
# -----------------------
# CONFIG
# -----------------------
pulse_samples = 1000     # n_feat_muon
n_feat_frec = 2500       # n_feat_frec
batch_size = 256
epochs = 80
lr = 1e-3
device = "cuda" if torch.cuda.is_available() else "cpu"
n_classes = 21

# Paths a tus datasets
muon_dataset_path = "muon_dataset_segmented_v3.npz"
simulated_npz_path = "Espectros/spectrum_simulated.npz"
real_npz_path = "Espectros/spectrum_real.npz"

print("Device:", device)



# -----------------------
# CARGA DE DATASET DE MUONES
# -----------------------
data = np.load(muon_dataset_path)
X_muones = data['X']        # shape (num_pulsos, pulse_samples)
y_muones = data['y']        # shape (num_pulsos,)

# -----------------------
# Normalizar pulsos de muones al mismo rango
# -----------------------
# Tomar el máximo global de todos los pulsos
max_global = X_muones.max()

# Escalar todos los pulsos para que el pulso con mayor valor llegue a 1
X_muones = X_muones / (max_global + 1e-8)  # evitar división por cero

# Convertir a tensores PyTorch
X_muones = torch.tensor(X_muones, dtype=torch.float32).unsqueeze(1)  # (N,1,pulse_samples)
y_muones = torch.tensor(y_muones, dtype=torch.long).squeeze()         # (N,)

print(f"Señales de muones: {X_muones.shape}, targets: {y_muones.shape}")




# -----------------------
# CARGA DE ESPECTROS
# -----------------------
def load_npz(path):
    data = np.load(path)
    freq = data['freq']
    att = data['attenuation_db']
    return torch.tensor(freq, dtype=torch.float32), torch.tensor(att, dtype=torch.float32)

sim_freq, H_sim = load_npz(simulated_npz_path)
real_freq, H_real = load_npz(real_npz_path)

# Repetir para cada ejemplo
H_sim_batch = H_sim.repeat(X_muones.shape[0], 1)  # (N, n_feat_frec)
# Out:
# Device: cuda
# Señales de muones: torch.Size([10000, 1, 1000]), targets: torch.Size([10000])

# %%
# -----------------------
# DEFINICIÓN DE LA RED
# -----------------------
class TwoBranchNet(nn.Module):
    def __init__(self, n_feat_muon=1000, n_feat_frec=2500, n_classes=21):
        super(TwoBranchNet, self).__init__()
        
        # --- Rama CNN Muones ---
        self.cnn_branch = nn.Sequential(
            nn.Conv1d(1, 64, kernel_size=15, padding='same'),
            nn.BatchNorm1d(64),
            nn.LeakyReLU(0.1),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, kernel_size=7, padding='same'),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.1),         
            nn.MaxPool1d(2),
            

            nn.Conv1d(128, 256, kernel_size=5, padding='same'),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.1),
            nn.AdaptiveAvgPool1d(1),  # (batch, 256, 1)
            nn.Flatten()
        )
        
        # Rama 2: Respuesta en frecuencia simulada (MLP)
        self.mlp_branch = nn.Sequential(
            nn.Linear(n_feat_frec, 128),
            nn.LeakyReLU(0.1),
            nn.Linear(128, 64),
            nn.LeakyReLU(0.1),
            nn.Linear(64, 32),
            nn.LeakyReLU(0.1)
        )

        # --- Cabezal de fusión ---
        self.head = nn.Sequential(
            nn.Linear(256 + 32, 256),
            nn.LeakyReLU(0.1),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.3),
            nn.Linear(128, n_classes)
        )
        
    def forward(self, x_muon, x_freq):
        v1 = self.cnn_branch(x_muon)
        v1 = v1.view(v1.size(0), -1)
        v2 = self.mlp_branch(x_freq)
        merged = torch.cat([v1, v2], dim=1)
        out = self.head(merged)
        return out

# -----------------------
# Inicializar modelo
# -----------------------
model = TwoBranchNet(n_feat_muon=pulse_samples, n_feat_frec=n_feat_frec, n_classes=n_classes).to(device)
summary(model, input_size=[(1,1,1000), (1,2500)])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TwoBranchNet                             [1, 21]                   --
# ├─Sequential: 1-1                        [1, 256]                  --
# │    └─Conv1d: 2-1                       [1, 64, 1000]             1,024
# │    └─BatchNorm1d: 2-2                  [1, 64, 1000]             128
# │    └─LeakyReLU: 2-3                    [1, 64, 1000]             --
# │    └─MaxPool1d: 2-4                    [1, 64, 500]              --
# │    └─Conv1d: 2-5                       [1, 128, 500]             57,472
# │    └─BatchNorm1d: 2-6                  [1, 128, 500]             256
# │    └─LeakyReLU: 2-7                    [1, 128, 500]             --
# │    └─MaxPool1d: 2-8                    [1, 128, 250]             --
# │    └─Conv1d: 2-9                       [1, 256, 250]             164,096
# │    └─BatchNorm1d: 2-10                 [1, 256, 250]             512
# │    └─LeakyReLU: 2-11                   [1, 256, 250]             --
# │    └─AdaptiveAvgPool1d: 2-12           [1, 256, 1]               --
# │    └─Flatten: 2-13                     [1, 256]                  --
# ├─Sequential: 1-2                        [1, 32]                   --
# │    └─Linear: 2-14                      [1, 128]                  320,128
# │    └─LeakyReLU: 2-15                   [1, 128]                  --
# │    └─Linear: 2-16                      [1, 64]                   8,256
# │    └─LeakyReLU: 2-17                   [1, 64]                   --
# │    └─Linear: 2-18                      [1, 32]                   2,080
# │    └─LeakyReLU: 2-19                   [1, 32]                   --
# ├─Sequential: 1-3                        [1, 21]                   --
# │    └─Linear: 2-20                      [1, 256]                  73,984
# │    └─LeakyReLU: 2-21                   [1, 256]                  --
# │    └─Linear: 2-22                      [1, 128]                  32,896
# │    └─LeakyReLU: 2-23                   [1, 128]                  --
# │    └─Dropout: 2-24                     [1, 128]                  --
# │    └─Linear: 2-25                      [1, 21]                   2,709
# ==========================================================================================
# Total params: 663,541
# Trainable params: 663,541
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 71.22
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.08
# Params size (MB): 2.65
# Estimated Total Size (MB): 5.75
# ==========================================================================================

# %%
# -----------------------
# Datasets y DataLoaders
# -----------------------

dataset = TensorDataset(X_muones, H_sim_batch, y_muones)

# Primer split: Train+Val vs Test (80/20)
n_total = len(dataset)
n_trainval = int(0.8 * n_total)
n_test = n_total - n_trainval
trainval_dataset, test_dataset = random_split(dataset, [n_trainval, n_test])

# Segundo split: Train vs Val (70/30 del 80%)
n_train = int(0.7 * n_trainval)
n_val  = n_trainval - n_train
train_dataset, val_dataset = random_split(trainval_dataset, [n_train, n_val])

# Configurar los DataLoaders. Usar 'sampler' para el de entrenamiento
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_dataset)}, Val size: {len(val_dataset)}, Test size: {len(test_dataset)}")






# -----------------------
# Inicialización de modelo, optimizer y scheduler
# -----------------------
model = TwoBranchNet(n_feat_muon=pulse_samples, n_feat_frec=n_feat_frec, n_classes=n_classes).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=3)








# -----------------------
# Custom Loss: CrossEntropy + Penalización
# -----------------------
def custom_loss_strong(outputs, targets, min_prob=0.05): 
    """ 
    CrossEntropy + penalización fuerte si alguna clase presente no se predice. 
    min_prob: probabilidad mínima que queremos para cada clase presente
    """ 
    ce = nn.CrossEntropyLoss()(outputs, targets) 

    probs = torch.softmax(outputs, dim=1) 
    batch_size = targets.size(0) 
    present_classes = torch.unique(targets) 

    penalty = 0.0 
    for c in present_classes: # fracción de ejemplos predichos como c 
        pred_fraction = (probs.argmax(dim=1) == c).float().mean() # penalizamos si pred_fraction < min_prob 

        penalty += torch.relu(min_prob - pred_fraction) # promedio sobre las clases presentes 

        penalty = penalty / len(present_classes) 
        
    return ce + 100.0 * penalty # multiplicador fuerte



# -----------------------
# Entrenamiento
# -----------------------
train_losses, val_losses = [], []
train_accs, val_accs = [], []

for epoch in range(epochs):
    model.train()
    running_loss, running_corrects = 0.0, 0
    for x_muon_batch, x_freq_batch, y_batch in train_loader:
        x_muon_batch = x_muon_batch.to(device)
        x_freq_batch = x_freq_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        output = model(x_muon_batch, x_freq_batch)
        loss = custom_loss_strong(output, y_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * x_muon_batch.size(0)
        preds = output.argmax(dim=1)
        running_corrects += (preds == y_batch).sum().item()

    epoch_loss = running_loss / n_train
    epoch_acc  = running_corrects / n_train
    train_losses.append(epoch_loss)
    train_accs.append(epoch_acc)

    # ---- Validation ----
    model.eval()
    val_running_loss, val_running_corrects = 0.0, 0
    with torch.no_grad():
        for x_muon_batch, x_freq_batch, y_batch in val_loader:
            x_muon_batch = x_muon_batch.to(device)
            x_freq_batch = x_freq_batch.to(device)
            y_batch = y_batch.to(device)

            val_output = model(x_muon_batch, x_freq_batch)
            val_loss = custom_loss_strong(val_output, y_batch)

            val_running_loss += val_loss.item() * x_muon_batch.size(0)
            preds = val_output.argmax(dim=1)
            val_running_corrects += (preds == y_batch).sum().item()

    val_epoch_loss = val_running_loss / n_val
    val_epoch_acc  = val_running_corrects / n_val
    val_losses.append(val_epoch_loss)
    val_accs.append(val_epoch_acc)

    scheduler.step(val_epoch_acc)

    print(f"Epoch {epoch+1}/{epochs} | "
          f"Train Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.4f} | "
          f"Val Loss: {val_epoch_loss:.4f}, Acc: {val_epoch_acc:.4f}")

# -----------------------
# Guardar pesos
# -----------------------
os.makedirs("model_weights", exist_ok=True)
torch.save(model.state_dict(), "model_weights/two_branch_net.pth")
print("Pesos guardados en 'model_weights/two_branch_net.pth'")

# -----------------------
# Evaluación y métricas
# -----------------------
model.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for x_muon_batch, x_freq_batch, y_batch in test_loader:
        x_muon_batch = x_muon_batch.to(device)
        x_freq_batch = x_freq_batch.to(device)
        y_batch = y_batch.to(device)

        output = model(x_muon_batch, x_freq_batch)
        preds = output.argmax(dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y_batch.cpu().numpy())

# Matriz de confusión
cm = confusion_matrix(all_labels, all_preds, labels=list(range(n_classes)))
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicción")
plt.ylabel("Etiqueta real")
plt.title("Matriz de Confusión")
plt.show()

# Reporte de clasificación
print("\nReporte de Clasificación:")
print(classification_report(all_labels, all_preds, digits=4))

# -----------------------
# Plot de pérdida y accuracy
# -----------------------
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.xlabel("Época")
plt.ylabel("CrossEntropy Loss")
plt.title("Pérdida")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.plot(train_accs, label="Train Acc")
plt.plot(val_accs, label="Val Acc")
plt.xlabel("Época")
plt.ylabel("Accuracy")
plt.title("Precisión")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Train size: 5600, Val size: 2400, Test size: 2000
# Epoch 1/80 | Train Loss: 2.1918, Acc: 0.4587 | Val Loss: 2.1678, Acc: 0.3742
# Epoch 2/80 | Train Loss: 1.4457, Acc: 0.6546 | Val Loss: 1.3658, Acc: 0.6471
# Epoch 3/80 | Train Loss: 1.4665, Acc: 0.6863 | Val Loss: 1.3103, Acc: 0.6379
# Epoch 4/80 | Train Loss: 1.4011, Acc: 0.7100 | Val Loss: 1.2379, Acc: 0.6779
# Epoch 5/80 | Train Loss: 1.3490, Acc: 0.7150 | Val Loss: 2.7435, Acc: 0.2558
# Epoch 6/80 | Train Loss: 1.3247, Acc: 0.7143 | Val Loss: 2.2233, Acc: 0.3038
# Epoch 7/80 | Train Loss: 1.3057, Acc: 0.7177 | Val Loss: 1.5489, Acc: 0.5617
# Epoch 8/80 | Train Loss: 1.3139, Acc: 0.7129 | Val Loss: 1.2623, Acc: 0.6967
# Epoch 9/80 | Train Loss: 1.2981, Acc: 0.7046 | Val Loss: 1.1452, Acc: 0.7242
# Epoch 10/80 | Train Loss: 1.4223, Acc: 0.7250 | Val Loss: 1.3710, Acc: 0.6362
# Epoch 11/80 | Train Loss: 1.2804, Acc: 0.7212 | Val Loss: 1.1509, Acc: 0.7150
# Epoch 12/80 | Train Loss: 1.2741, Acc: 0.7377 | Val Loss: 2.7546, Acc: 0.4717
# Epoch 13/80 | Train Loss: 1.3452, Acc: 0.7350 | Val Loss: 1.2745, Acc: 0.6450
# Epoch 14/80 | Train Loss: 1.2368, Acc: 0.7402 | Val Loss: 1.2453, Acc: 0.6846
# Epoch 15/80 | Train Loss: 1.2827, Acc: 0.7441 | Val Loss: 1.2653, Acc: 0.6604
# Epoch 16/80 | Train Loss: 1.2952, Acc: 0.7370 | Val Loss: 1.1055, Acc: 0.7483
# Epoch 17/80 | Train Loss: 1.2594, Acc: 0.7393 | Val Loss: 1.1662, Acc: 0.7054
# Epoch 18/80 | Train Loss: 1.2134, Acc: 0.7405 | Val Loss: 1.1015, Acc: 0.7488
# Epoch 19/80 | Train Loss: 1.2941, Acc: 0.7395 | Val Loss: 1.7378, Acc: 0.6008
# Epoch 20/80 | Train Loss: 1.2421, Acc: 0.7366 | Val Loss: 1.4253, Acc: 0.5858
# Epoch 21/80 | Train Loss: 1.2450, Acc: 0.7461 | Val Loss: 1.1032, Acc: 0.7512
# Epoch 22/80 | Train Loss: 1.2578, Acc: 0.7504 | Val Loss: 1.2465, Acc: 0.6850
# Epoch 23/80 | Train Loss: 1.2485, Acc: 0.7479 | Val Loss: 1.0689, Acc: 0.7596
# Epoch 24/80 | Train Loss: 1.2427, Acc: 0.7591 | Val Loss: 1.0743, Acc: 0.7671
# Epoch 25/80 | Train Loss: 1.2312, Acc: 0.7584 | Val Loss: 1.4719, Acc: 0.6083
# Epoch 26/80 | Train Loss: 1.1125, Acc: 0.7555 | Val Loss: 1.0911, Acc: 0.7512
# Epoch 27/80 | Train Loss: 1.2269, Acc: 0.7598 | Val Loss: 1.0397, Acc: 0.7671
# Epoch 28/80 | Train Loss: 1.2577, Acc: 0.7493 | Val Loss: 1.5204, Acc: 0.5954
# Epoch 29/80 | Train Loss: 1.2648, Acc: 0.7577 | Val Loss: 1.0534, Acc: 0.7679
# Epoch 30/80 | Train Loss: 1.2115, Acc: 0.7488 | Val Loss: 1.1554, Acc: 0.7204
# Epoch 31/80 | Train Loss: 1.2056, Acc: 0.7552 | Val Loss: 1.1728, Acc: 0.7133
# Epoch 32/80 | Train Loss: 1.1991, Acc: 0.7602 | Val Loss: 1.0790, Acc: 0.7288
# Epoch 33/80 | Train Loss: 1.1439, Acc: 0.7564 | Val Loss: 0.9963, Acc: 0.7021
# Epoch 34/80 | Train Loss: 1.1776, Acc: 0.7543 | Val Loss: 1.0674, Acc: 0.7488
# Epoch 35/80 | Train Loss: 1.1989, Acc: 0.7634 | Val Loss: 1.0504, Acc: 0.7696
# Epoch 36/80 | Train Loss: 1.1356, Acc: 0.7648 | Val Loss: 1.0594, Acc: 0.7654
# Epoch 37/80 | Train Loss: 1.2173, Acc: 0.7566 | Val Loss: 1.0537, Acc: 0.7650
# Epoch 38/80 | Train Loss: 1.2347, Acc: 0.7579 | Val Loss: 1.0856, Acc: 0.7579
# Epoch 39/80 | Train Loss: 1.2261, Acc: 0.7584 | Val Loss: 1.0617, Acc: 0.7633
# Epoch 40/80 | Train Loss: 1.1775, Acc: 0.7632 | Val Loss: 1.0755, Acc: 0.7588
# Epoch 41/80 | Train Loss: 1.1762, Acc: 0.7616 | Val Loss: 1.0277, Acc: 0.7742
# Epoch 42/80 | Train Loss: 1.2445, Acc: 0.7655 | Val Loss: 1.0312, Acc: 0.7742
# Epoch 43/80 | Train Loss: 1.2297, Acc: 0.7643 | Val Loss: 1.0433, Acc: 0.7708
# Epoch 44/80 | Train Loss: 1.1994, Acc: 0.7638 | Val Loss: 1.0371, Acc: 0.7692
# Epoch 45/80 | Train Loss: 1.1936, Acc: 0.7661 | Val Loss: 1.0306, Acc: 0.7750
# Epoch 46/80 | Train Loss: 1.1726, Acc: 0.7625 | Val Loss: 1.0390, Acc: 0.7654
# Epoch 47/80 | Train Loss: 1.1992, Acc: 0.7609 | Val Loss: 0.9742, Acc: 0.7588
# Epoch 48/80 | Train Loss: 1.2389, Acc: 0.7650 | Val Loss: 1.0220, Acc: 0.7750
# Epoch 49/80 | Train Loss: 1.1761, Acc: 0.7654 | Val Loss: 1.0184, Acc: 0.7558
# Epoch 50/80 | Train Loss: 1.2667, Acc: 0.7605 | Val Loss: 1.0398, Acc: 0.7754
# Epoch 51/80 | Train Loss: 1.1743, Acc: 0.7636 | Val Loss: 1.0571, Acc: 0.7679
# Epoch 52/80 | Train Loss: 1.2576, Acc: 0.7639 | Val Loss: 1.0290, Acc: 0.7742
# Epoch 53/80 | Train Loss: 1.1963, Acc: 0.7650 | Val Loss: 1.0409, Acc: 0.7721
# Epoch 54/80 | Train Loss: 1.1422, Acc: 0.7641 | Val Loss: 1.0447, Acc: 0.7688
# Epoch 55/80 | Train Loss: 1.2538, Acc: 0.7696 | Val Loss: 1.0284, Acc: 0.7750
# Epoch 56/80 | Train Loss: 1.1553, Acc: 0.7675 | Val Loss: 1.0415, Acc: 0.7721
# Epoch 57/80 | Train Loss: 1.1689, Acc: 0.7696 | Val Loss: 1.0335, Acc: 0.7754
# Epoch 58/80 | Train Loss: 1.1785, Acc: 0.7675 | Val Loss: 1.0399, Acc: 0.7712
# Epoch 59/80 | Train Loss: 1.2033, Acc: 0.7700 | Val Loss: 1.0394, Acc: 0.7712
# Epoch 60/80 | Train Loss: 1.2113, Acc: 0.7671 | Val Loss: 1.0393, Acc: 0.7725
# Epoch 61/80 | Train Loss: 1.2290, Acc: 0.7695 | Val Loss: 1.0335, Acc: 0.7758
# Epoch 62/80 | Train Loss: 1.2182, Acc: 0.7654 | Val Loss: 1.0233, Acc: 0.7738
# Epoch 63/80 | Train Loss: 1.1699, Acc: 0.7650 | Val Loss: 1.0409, Acc: 0.7725
# Epoch 64/80 | Train Loss: 1.2492, Acc: 0.7696 | Val Loss: 1.0337, Acc: 0.7712
# Epoch 65/80 | Train Loss: 1.2002, Acc: 0.7712 | Val Loss: 1.0291, Acc: 0.7721
# Epoch 66/80 | Train Loss: 1.1832, Acc: 0.7657 | Val Loss: 1.0290, Acc: 0.7721
# Epoch 67/80 | Train Loss: 1.1920, Acc: 0.7700 | Val Loss: 1.0286, Acc: 0.7738
# Epoch 68/80 | Train Loss: 1.2221, Acc: 0.7664 | Val Loss: 1.0332, Acc: 0.7733
# Epoch 69/80 | Train Loss: 1.2255, Acc: 0.7695 | Val Loss: 1.0230, Acc: 0.7775
# Epoch 70/80 | Train Loss: 1.1997, Acc: 0.7657 | Val Loss: 1.0400, Acc: 0.7729
# Epoch 71/80 | Train Loss: 1.1508, Acc: 0.7673 | Val Loss: 1.0290, Acc: 0.7721
# Epoch 72/80 | Train Loss: 1.1895, Acc: 0.7627 | Val Loss: 1.0289, Acc: 0.7721
# Epoch 73/80 | Train Loss: 1.1364, Acc: 0.7648 | Val Loss: 1.0422, Acc: 0.7721
# Epoch 74/80 | Train Loss: 1.2921, Acc: 0.7673 | Val Loss: 1.0287, Acc: 0.7717
# Epoch 75/80 | Train Loss: 1.2483, Acc: 0.7695 | Val Loss: 1.0286, Acc: 0.7738
# Epoch 76/80 | Train Loss: 1.2373, Acc: 0.7682 | Val Loss: 1.0229, Acc: 0.7775
# Epoch 77/80 | Train Loss: 1.1555, Acc: 0.7657 | Val Loss: 1.0286, Acc: 0.7721
# Epoch 78/80 | Train Loss: 1.2621, Acc: 0.7668 | Val Loss: 1.0287, Acc: 0.7721
# Epoch 79/80 | Train Loss: 1.2289, Acc: 0.7695 | Val Loss: 1.0285, Acc: 0.7742
# Epoch 80/80 | Train Loss: 1.2031, Acc: 0.7629 | Val Loss: 1.0230, Acc: 0.7775
# Pesos guardados en 'model_weights/two_branch_net.pth'
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         6
#            1     0.0000    0.0000    0.0000         5
#            2     0.0000    0.0000    0.0000         8
#            3     0.0000    0.0000    0.0000        28
#            4     0.0000    0.0000    0.0000        93
#            5     0.4936    0.7444    0.5936       313
#            6     0.8006    0.7745    0.7873       736
#            7     0.9506    0.9625    0.9565       800
#            8     1.0000    0.5455    0.7059        11
#
#     accuracy                         0.7895      2000
#    macro avg     0.3605    0.3363    0.3381      2000
# weighted avg     0.7576    0.7895    0.7691      2000
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# -----------------------
# Evaluación en Test
# -----------------------
model.eval()
test_preds_all = []
test_targets_all = []

with torch.no_grad():
    for x_muon_batch, x_freq_batch, y_batch in test_loader:
        x_muon_batch = x_muon_batch.to(device)
        x_freq_batch = x_freq_batch.to(device)
        y_batch = y_batch.to(device)

        test_output = model(x_muon_batch, x_freq_batch)
        preds = test_output.argmax(dim=1)   # <- argmax para clases
        test_preds_all.append(preds.cpu())
        test_targets_all.append(y_batch.cpu())

# Concatenar todos los batches
test_preds_all = torch.cat(test_preds_all)
test_targets_all = torch.cat(test_targets_all)

# Accuracy
acc_test = accuracy_score(test_targets_all.numpy(), test_preds_all.numpy())
print(f"Accuracy en Test: {acc_test*100:.2f}%")

# Histograma de clases predichas vs reales
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.hist(test_targets_all.numpy(), bins=np.arange(-0.5, 21.5, 1), alpha=0.6, label="Target", edgecolor='k')
plt.hist(test_preds_all.numpy(), bins=np.arange(-0.5, 21.5, 1), alpha=0.6, label="Predicción", edgecolor='k')
plt.xlabel("Clase")
plt.ylabel("Cantidad")
plt.title("Distribución de clases en Test")
plt.legend()
plt.grid(True)
# Out:
# Accuracy en Test: 78.95%
